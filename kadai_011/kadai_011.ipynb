# %%
list = ["水","金","地","火","木","土","天","海","冥"]

# for文で出力
for value in list:
  print(value)

# while文で出力
index = 0 # listのインデックス値を代入する用の変数　初期値を設定

while index < 9:
    print(list[index])
    index = index + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
